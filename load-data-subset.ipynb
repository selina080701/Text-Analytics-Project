# %% [markdown]
# # Dataset Loader: Genius Song Lyrics (Hugging Face)
#
# **Data Source:** https://huggingface.co/datasets/sebastiandizon/genius-song-lyrics
#
# **Description:** The original Genius Song Lyrics dataset contains 2.76 million songs (~9 GB CSV file). To enable lightweight experimentation, this script allows you to download and save a smaller random subset (e.g., 1%) locally as CSV.
#
# ---

# %% [markdown]
# ## 1. Preparations
# ### 1.1 Import Packages

# %%
from datasets import load_dataset
import pandas as pd
import os

# %% [markdown]
# ### 1.2 Configuration
#
# * Define the subset percentage to download (e.g., 1%, 5%, 10%). Note: Hugging Face only accepts integer percentages for split notation.
# * Define output directory and file name.
# * Create directory if it doesn't exist.

# %%
subset_fraction = 1

output_dir = "data"
output_path = f"{output_dir}/lyrics_subset_{subset_fraction}pct.csv"

os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ## 2. Load and Save Dataset
# ### 2.1 Load Subset of Dataset from Hugging Face

# %%
print(f"Loading Subset: {subset_fraction}% of total dataset\n")

dataset = load_dataset("sebastiandizon/genius-song-lyrics", split=f"train[:{subset_fraction}%]")

print(f"Dataset loaded successfully with {len(dataset):,} entries.")
# Out:
# Loading Subset: 1% of total dataset
#
# Dataset loaded successfully with 51,349 entries.

# %% [markdown]
# ### 2.2 Convert to pandas DataFrame

# %%
df = dataset.to_pandas()

print(f"DataFrame shape: {df.shape}")

print(f"Number of Songs: {len(df)} | Artists: {df['artist'].nunique()}")
# Out:
# DataFrame shape: (51349, 11)
# Number of Songs: 51349 | Artists: 5333

# %% [markdown]
# ### 2.3 Save Subset locally

# %%
df.to_csv(output_path, index=False)

print(f"Subset saved: {output_path}")
# Out:
# Subset saved: data/lyrics_subset_1pct.csv

# %% [markdown]
# ## 3. Preview of dataset

# %%
df
# Out:
#                      title  tag             artist  year   views  \
# 0                Killa Cam  rap            Cam'ron  2004  173166
# 1               Can I Live  rap              JAY-Z  1996  468624
# 2        Forgive Me Father  rap           Fabolous  2003    4743
# 3             Down and Out  rap            Cam'ron  2004  144404
# 4                   Fly In  rap          Lil Wayne  2005   78271
# ...                    ...  ...                ...   ...     ...
# 51344            Pac Blood  rap        Danny Brown  2011   87745
# 51345           15 Minutes  rap       Hasan Salaam  2011     104
# 51346   Scheiß auf den Rat  rap             Nate57  2011    3022
# 51347  Catch Me If You Can  rap  Shawn Chrystopher  2011    2241
# 51348              Jackpot  rap             Nate57  2011    1921
#
#                                            features  \
# 0                       {"Cam\\'ron","Opera Steve"}
# 1                                                {}
# 2                                                {}
# 3      {"Cam\\'ron","Kanye West","Syleena Johnson"}
# 4                                                {}
# ...                                             ...
# 51344                                            {}
# 51345                                            {}
# 51346                                            {}
# 51347                                            {}
# 51348                                         {BOZ}
#
#                                                   lyrics     id language_cld3  \
# 0      [Chorus: Opera Steve & Cam'ron]\nKilla Cam, Ki...      1            en
# 1      [Produced by Irv Gotti]\n\n[Intro]\nYeah, hah,...      3            en
# 2      Maybe cause I'm eatin\nAnd these bastards fien...      4            en
# 3      [Produced by Kanye West and Brian Miller]\n\n[...      5            en
# 4      [Intro]\nSo they ask me\n"Young boy\nWhat you ...      6            en
# ...                                                  ...    ...           ...
# 51344  [Verse 1]\nThe Shakespeare of sixteens, dippin...  54417            en
# 51345  [Verse 1]\nI'm trying to shake of the blues\nS...  57114            en
# 51346  [Verse 1:]\nIch fall' im Traum auf die Straße,...  54426            de
# 51347  [Verse 1: Shawn Chrystopher]\nTell me who fuck...  54427            en
# 51348  [Verse 1:]\nWir haben den Jackpot geknackt par...  54428            de
#
#       language_ft language
# 0              en       en
# 1              en       en
# 2              en       en
# 3              en       en
# 4              en       en
# ...           ...      ...
# 51344          en       en
# 51345          en       en
# 51346          de       de
# 51347          en       en
# 51348          de       de
#
# [51349 rows x 11 columns]
